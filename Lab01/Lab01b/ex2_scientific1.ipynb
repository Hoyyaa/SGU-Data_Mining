# %% [markdown]
# # ex2_scientific1
#
# ## Nội dung bài
# Hiển thị ngẫu nhiên $N = 50$ hình tròn:
# + Tâm $c_i = (x_i,y_i)$ ngẫu nhiên với $x_i, y_i \in \left[0, 1 \right]$
# + Màu sắc $color_i$ ngẫu nhiên với $color_i \in \left[0, 1 \right]$
# + Diện tích $area_i = \pi * r_i^2$ với sinh ngẫu nhiên $r_i \in \left[0, 1 \right]$
#
# ## Bài làm

# %% [markdown]
# ### Import thư viện

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython import display # hiển thị rich output

# %% [markdown]
# ### Sinh ngẫu nhiên hình tròn

# %%
# %time
#generate randomly the center (x,y) of circle, color, area
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N)) ** 2 # 0 to 15 point
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns

# %%
# Mã kiểm tra dữ liệu
print(f' + x: len={len(x):d}, [{min(x):.2f}, {max(x):.2f}]: 10 samples [{x[0:10]}]')
print(f' + y: len={len(y):d}, [{min(y):.2f}, {max(y):.2f}]: 10 samples [{y[0:10]}]')
print(f' + colors: len={len(colors):d}, [{min(colors):.2f}, {max(colors):.2f}]: 10 samples [{colors[0:10]}]')
print(f' + area: len={len(area):d}, [{min(area):.2f}, {max(area):.2f}]: 10 samples [{area[0:10]}]')
# Out:
#  + x: len=50, [0.01, 0.99]: 10 samples [[0.25281019 0.60266312 0.91328412 0.8664411  0.86530266 0.21343773
#  0.27618723 0.39829668 0.0864278  0.69961377]]
#  + y: len=50, [0.03, 0.96]: 10 samples [[0.58893109 0.6209237  0.3461709  0.47898001 0.58945562 0.73190178
#  0.49834377 0.17174146 0.42261846 0.19562533]]
#  + colors: len=50, [0.02, 0.99]: 10 samples [[0.14910287 0.41872626 0.87556545 0.63786365 0.37792796 0.20162768
#  0.95704315 0.17558134 0.06716642 0.51204303]]
#  + area: len=50, [4.20, 640.43]: 10 samples [[ 89.07623209 493.48705359 214.86500765 268.69513966  68.89624897
#   70.94833106  12.66701109 242.6768061  123.14335207 258.8705537 ]]

# %% [markdown]
# ### Hiển thị đồ thị

# %%
# %matplotlib inline
plt.scatter(x, y, s = area, c = colors, alpha = 0.5)
plt.show()

# %% [markdown]
# # Kết thúc
