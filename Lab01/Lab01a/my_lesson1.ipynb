# %% [markdown]
# # Thực hành trí tuệ nhân tạo Buổi 1
# ## Nội dung thực hành

# %% [markdown]
# ### In chữ ra màn hình

# %%
# Lệnh 1 - Xuất chữ
print("Hello, Python World!")
# Out:
# Hello, Python World!

# %% [markdown]
# ### Chạy tập tin Python

# %%
# !python ex0_hello_world.py
# Out:
# Hello, Python World!

# %%
# %run ex0_hello_world.py
# Out:
# Hello, Python World!

# %% [markdown]
# ### Tính toán đơn giản

# %%
# %run ex1_calc.py
# Out:
# Calculator Basic
# Mời bạn nhập số a:  10
# Mời bạn nhập số b:  15
# c = 10 + 15 = 25

# %%
print("Calculator Basic")
a = int(input("Mời bạn nhập số a: "))
b = int(input("Mời bạn nhập số b: "))
c = a + b
print("c = %d + %d = %d" % (a, b, c))
# Out:
# Calculator Basic
# Mời bạn nhập số a:  10
# Mời bạn nhập số b:  15
# c = 10 + 15 = 25

# %% [markdown]
# ### Hình tròn

# %%
# %run ex3_circle.py
# Out:
# Enter r =
#  4
# Chu vi hình tròn là:  25.12
# Diện tích hình tròn là:  50.24

# %% [markdown]
# # Kết thúc
